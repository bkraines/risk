# %%
from risk_data import get_factor_data
from risk_config import CACHE_TARGET
print(f'Caching data to {CACHE_TARGET}')
# Out:
# Caching data to disk

# %% [markdown]
# Default parameters -- Checks cache. Uses cache if it's current. Redownloads data if it's stale.

# %%
factor_data = get_factor_data()
# Out:
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)

# %% [markdown]
# Forced redownload -- Always downloads data

# %%
factor_data = get_factor_data(read_cache=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)
# ...

# %%
print(factor_data)
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:        (date: 8124, factor_name: 5, vol_type: 5, factor_name_1: 5,
#                     corr_type: 5)
# Coordinates:
#   * date           (date) datetime64[ns] 65kB 1993-01-29 ... 2025-05-07
#   * factor_name    (factor_name) object 40B 'SPY' 'IWM' 'MDY' 'RSP' 'QQQ'
#   * vol_type       (vol_type) int64 40B 21 63 126 252 512
#   * factor_name_1  (factor_name_1) object 40B 'SPY' 'IWM' 'MDY' 'RSP' 'QQQ'
#   * corr_type      (corr_type) int64 40B 21 63 126 252 512
# Data variables:
#     ret            (date, factor_name) float64 325kB nan nan nan ... 65.86 39.26
#     cret           (date, factor_name) float64 325kB nan nan nan ... 171.2 483.3
#     vol            (vol_type, date, factor_name) float64 2MB nan nan ... 23.81
#     corr           (corr_type, date, factor_name, factor_name_1) float64 8MB ...

# %% [markdown]
# Forced cache read -- Always return cache, even if it's stale

# %%
factor_data = get_factor_data(read_cache=True, check=None)
factor_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)
# ...

# %%
get_factor_data(read_cache=False, factor_set='read_short')

# %%
import yfinance as yf
yf.download('SPY', start='2020-01-01', end='2020-12-31', progress=False).head()
