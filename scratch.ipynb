# %%
import xarray as xr
import pandas as pd
from risk_util import to_pandas_strict

# Example: 0D DataArray
da_0d = xr.DataArray(
    5.5,  # Scalar value
    coords={},
    dims=[]
)

print("\n--- 0D DataArray.to_pandas() ---")
print(type(da_0d.to_pandas()))  # Should return xarray.DataArray
print(da_0d.to_pandas())

print("\n--- 0D DataArray.to_pandas_strict() ---")
print(type(to_pandas_strict(da_0d)))  # Should return pandas.Series
print(to_pandas_strict(da_0d))  # Should return pandas.Series with scalar value

# %%
from risk_util import to_pandas_strict
da_0d.to_pandas_strict()

# %%
from risk_data import get_factor_data

factor_data = get_factor_data()
# Out:
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)
# c:\Users\bkrai\Source\venv-bklm\Lib\site-packages\zarr\codecs\vlen_utf8.py:44: UserWarning: The codec `vlen-utf8` is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   return cls(**configuration_parsed)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IWM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ...

# %%
import yfinance as yf
yf.download("AAPL", start="2020-01-01", end="2020-12-31", progress=False)
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.716072   72.776598   71.466812   71.721019  135480400
# 2020-01-03   72.009125   72.771752   71.783969   71.941336  146322800
# 2020-01-06   72.582909   72.621646   70.876075   71.127866  118387200
# 2020-01-07   72.241562   72.849239   72.021246   72.592609  108872000
# 2020-01-08   73.403648   73.706279   71.943759   71.943759  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-23  127.919273  129.355128  127.743445  129.091408   88223700
# 2020-12-24  128.905777  130.361186  128.055982  128.270875   54930100
# 2020-12-28  133.516190  134.151091  130.410018  130.878884  124486200
# 2020-12-29  131.738464  135.567445  131.220772  134.844636  121047300
# 2020-12-30  130.615158  132.832455  130.302581  132.431971   96452100
#
# [252 rows x 5 columns]
